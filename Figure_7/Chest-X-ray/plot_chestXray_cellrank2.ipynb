# %% [markdown]
# # Determining patient fate

# %%
import scanpy as sc
import pandas as pd
import cellrank as cr
import ehrapy as ep
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
mpl.rcParams["pdf.fonttype"] = 42
mpl.rcParams["ps.fonttype"] = 42
sc.set_figure_params(vector_friendly=True, dpi_save=300)

# %%
df_annotations = pd.read_csv("public-annotations.csv")

filenames = pd.read_csv("filenames.csv", index_col=None)

df_annotations = df_annotations[
    df_annotations.filename.isin(list(filenames["filename"]))
].reset_index(drop=True)
df_annotations["geographic_mean"] = df_annotations["S-Global"]

# %%
# Old cutoff by XZ
df_annotations["geographic_mean"].replace(
    [
        0,
        1,
        2,
    ],
    "Normal",
    inplace=True,
)
df_annotations["geographic_mean"].replace([3, 4, 5], "Mild", inplace=True)
df_annotations["geographic_mean"].replace(
    [6, 7, 8, 9, 10, 11], "Moderate", inplace=True
)
df_annotations["geographic_mean"].replace(
    [12, 13, 14, 15, 16, 17, 18], "Severe", inplace=True
)

# %%
# New cutoff by PE/LH
normal_conditions = (
    df_annotations[["S-A", "S-B", "S-C", "S-D", "S-E", "S-F"]] == 0
).all(axis=1)
mild_conditions = (df_annotations[["S-A", "S-B", "S-C", "S-D", "S-E", "S-F"]] == 1).any(
    axis=1
) & (~((df_annotations[["S-A", "S-B", "S-C", "S-D", "S-E", "S-F"]] > 1).any(axis=1)))
moderate_conditions = (
    df_annotations[["S-A", "S-B", "S-C", "S-D", "S-E", "S-F"]] >= 2
).any(axis=1)
severe_conditions = (
    (df_annotations[["S-A", "S-B", "S-C", "S-D", "S-E", "S-F"]] == 3).any(axis=1)
) & (df_annotations["S-Global"] >= 7)
critical_conditions = (
    (df_annotations[["S-A", "S-B", "S-C", "S-D", "S-E", "S-F"]] == 3).sum(axis=1) >= 2
) & (df_annotations["S-Global"] >= 11)

df_annotations.loc[normal_conditions, "severity"] = "Normal"
df_annotations.loc[mild_conditions, "severity"] = "Mild"
df_annotations.loc[moderate_conditions, "severity"] = "Moderate"
df_annotations.loc[severe_conditions, "severity"] = "Severe"
df_annotations.loc[critical_conditions, "severity"] = "Critical"

# %%
df_annotations["severity"].value_counts()
# Out:
# severity
# Moderate    53
# Critical    37
# Severe      26
# Mild        22
# Normal      18
# Name: count, dtype: int64

# %%
adata = sc.read_csv(f"embeddings.csv")
adata.obs["geographic_mean"] = df_annotations["geographic_mean"].values
adata.obs["severity"] = df_annotations["severity"].values
adata.obs["image_name"] = filenames["filename"].values

# %%
# palette = {
#     "Normal": "yellowgreen",
#     "Mild": "turquoise",
#     "Moderate": "orange",
#     "Severe": "red",
#     "Critical": "purple"
# }

import matplotlib.colors as mcolors

palette = {
    "Normal": mcolors.to_rgba("#1CFF4B"),
    "Mild": mcolors.to_rgba("#04C6DB"),
    "Moderate": mcolors.to_rgba("#1222F0"),
    "Severe": mcolors.to_rgba("#AF00DB"),
    "Critical": mcolors.to_rgba("#FF1202"),
}

# %%
ep.pp.pca(adata)
ep.pp.neighbors(adata)
ep.tl.umap(adata, n_components=3)
ep.pl.umap(adata, color=["geographic_mean"], palette=palette)
ep.pl.umap(adata, color=["severity"], palette=palette, show=False)
plt.savefig("../figure_parts/severity.pdf", format="pdf")

# %%
adata.uns["iroot"] = np.flatnonzero(adata.obs["geographic_mean"] == "Normal")[10]
ep.tl.dpt(adata)
ep.pl.umap(adata, color="dpt_pseudotime", show=False)
plt.tight_layout()
plt.savefig("../figure_parts/pseudotime.pdf", format="pdf")
# Out:
# WARNING: Trying to run `tl.dpt` without prior call of `tl.diffmap`. Falling back to `tl.diffmap` with default parameters.

# %%
adata.uns["iroot"] = np.flatnonzero(adata.obs["geographic_mean"] == "Normal")[10]
ep.tl.dpt(adata)
pk = cr.kernels.PseudotimeKernel(adata, time_key="dpt_pseudotime")
pk.compute_transition_matrix(threshold_scheme="soft")
pk.plot_projection(
    basis="umap",
    stream=True,
    color="geographic_mean",
    density=1,
    smooth=True,
    size=4000,
)
# Out:
#   0%|          | 0/156 [00:00<?, ?cell/s]

# %%
adata.uns["iroot"] = np.flatnonzero(adata.obs["severity"] == "Normal")[10]
ep.tl.dpt(adata)
pk = cr.kernels.PseudotimeKernel(adata, time_key="dpt_pseudotime")
pk.compute_transition_matrix(threshold_scheme="soft")
# Out:
#   0%|          | 0/156 [00:00<?, ?cell/s]
# PseudotimeKernel[n=156, dnorm=False, scheme='soft', b=10.0, nu=0.5]

# %%
plt.rcParams["axes.grid"] = False
pk.plot_projection(
    basis="umap",
    stream=True,
    color="severity",
    density=1,
    smooth=True,
    size=850,
    add_margin=0.1,
    save="../figure_parts/project_flow.pdf",
)
# Out:
# saving figure to file ../figure_parts/project_flow.pdf

# %%
pk.plot_random_walks(
    basis="umap", start_ixs={"severity": ["Normal"]}, n_sims=100, ixs_legend_loc="best"
)
# Out:
#   0%|          | 0/100 [00:00<?, ?sim/s]

# %% [markdown]
# The images that are not quite where they should be:

# %% [markdown]
# **Normal**

# %%
ep.pl.umap(adata[adata.obs.geographic_mean == "Normal"], color="dpt_pseudotime")

# %%
normal_only = adata.obs[adata.obs.geographic_mean == "Normal"].sort_values(
    by="dpt_pseudotime"
)
normal_only
# Out:
#     geographic_mean  severity  \
# 148          Normal    Normal
# 152          Normal    Normal
# 151          Normal    Normal
# 145          Normal    Normal
# 153          Normal    Normal
# 106          Normal  Moderate
# 150          Normal    Normal
# 135          Normal  Moderate
# 118          Normal      Mild
# 155          Normal    Normal
# 149          Normal    Normal
# 134          Normal      Mild
# 146          Normal    Normal
# 117          Normal      Mild
# 136          Normal      Mild
# 141          Normal    Normal
# 144          Normal    Normal
# 137          Normal      Mild
# 142          Normal    Normal
# 114          Normal  Moderate
# 140          Normal    Normal
# 107          Normal      Mild
# 154          Normal    Normal
# 147          Normal    Normal
# 138          Normal      Mild
# 119          Normal    Normal
# 143          Normal    Normal
# 139          Normal      Mild
# 113          Normal      Mild
# 133          Normal      Mild
# 85           Normal    Normal
# 84           Normal      Mild
#
#                                             image_name  dpt_pseudotime
# 148                       covid-19-pneumonia-38-pa.jpg        0.000000
# 152                    covid-19-pneumonia-58-prior.jpg        0.063657
# 151                   covid-19-pneumonia-44-day-0.jpeg        0.098984
# 145                          covid-19-pneumonia-20.jpg        0.131560
# 153                    covid-19-pneumonia-58-day-9.jpg        0.142481
# 106                         legionella-pneumonia-2.jpg        0.217048
# 150                        covid-19-pneumonia-35-2.jpg        0.221323
# 135                          covid-19-pneumonia-40.jpg        0.234752
# 118  covid-19-pneumonia-evolution-over-a-week-1-day...        0.236816
# 155                        covid-19-pneumonia-mild.JPG        0.241555
# 149                        covid-19-pneumonia-35-1.jpg        0.247421
# 134                    covid-19-pneumonia-43-day2.jpeg        0.248272
# 146                  covid-19-pneumonia-22-day1-pa.png        0.251252
# 117  covid-19-pneumonia-evolution-over-a-week-1-day...        0.263543
# 136                         covid-19-pneumonia-42.jpeg        0.267903
# 141                       radiol.2020201160.fig3b.jpeg        0.285080
# 144          covid-19-pneumonia-20-pa-on-admission.jpg        0.287684
# 137  da9e9aac-de8c-44c7-ba57-e7cc8e4caaba.annot.ori...        0.290140
# 142                       radiol.2020201160.fig6b.jpeg        0.302020
# 114                    covid-19-pneumonia-24-day12.jpg        0.307264
# 140     figure1-5e7c1b8d98c29ab001275405-98-later.jpeg        0.311286
# 107  1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf...        0.317338
# 154                   covid-19-pneumonia-58-day-10.jpg        0.321379
# 147                          covid-19-pneumonia-34.png        0.321888
# 138  4ad30bc6-2da0-4f84-bc9b-62acabfd518a.annot.ori...        0.322785
# 119                     covid-19-pneumonia-23-day1.jpg        0.335472
# 143                        radiol.2020200274.fig3d.png        0.347317
# 139           figure1-5e7c1b8d98c29ab001275405-98.jpeg        0.356784
# 113                     covid-19-pneumonia-24-day7.jpg        0.368501
# 133                    covid-19-pneumonia-43-day0.jpeg        0.402957
# 85                        covid-19-pneumonia-30-PA.jpg        0.404067
# 84                 cavitating-pneumonia-4-day28-PA.png        0.504983

# %%
normal_only.loc["148"]
# Out:
# geographic_mean                          Normal
# severity                                 Normal
# image_name         covid-19-pneumonia-38-pa.jpg
# dpt_pseudotime                              0.0
# Name: 148, dtype: object

# %% [markdown]
# ## Mild

# %%
ep.pl.umap(adata[adata.obs.severity == "Mild"], color="dpt_pseudotime")

# %%
normal_only = adata.obs[adata.obs.severity == "Mild"].sort_values(
    by="dpt_pseudotime", ascending=False
)
normal_only
# Out:
#     geographic_mean severity  \
# 84           Normal     Mild
# 82         Moderate     Mild
# 90             Mild     Mild
# 128            Mild     Mild
# 133          Normal     Mild
# 113          Normal     Mild
# 116            Mild     Mild
# 139          Normal     Mild
# 100            Mild     Mild
# 123        Moderate     Mild
# 115            Mild     Mild
# 138          Normal     Mild
# 107          Normal     Mild
# 101            Mild     Mild
# 137          Normal     Mild
# 124        Moderate     Mild
# 136          Normal     Mild
# 117          Normal     Mild
# 134          Normal     Mild
# 125            Mild     Mild
# 118          Normal     Mild
# 102            Mild     Mild
#
#                                             image_name  dpt_pseudotime
# 84                 cavitating-pneumonia-4-day28-PA.png        0.504983
# 82                          chlamydia-pneumonia-PA.png        0.493893
# 90   covid-19-pneumonia-rapidly-progressive-3-days.jpg        0.437735
# 128  post-intubuation-pneumomediastium-and-pneumoth...        0.416809
# 133                    covid-19-pneumonia-43-day0.jpeg        0.402957
# 113                     covid-19-pneumonia-24-day7.jpg        0.368501
# 116  covid-19-pneumonia-evolution-over-a-week-1-day...        0.357087
# 139           figure1-5e7c1b8d98c29ab001275405-98.jpeg        0.356784
# 100                       pneumocystis-pneumonia-8.jpg        0.331687
# 123  RX-torace-a-letto-del-paziente-in-unica-proiez...        0.329663
# 115  covid-19-pneumonia-evolution-over-a-week-1-day...        0.323138
# 138  4ad30bc6-2da0-4f84-bc9b-62acabfd518a.annot.ori...        0.322785
# 107  1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf...        0.317338
# 101                      pneumocystis-pneumonia-12.png        0.315137
# 137  da9e9aac-de8c-44c7-ba57-e7cc8e4caaba.annot.ori...        0.290140
# 124                          covid-19-caso-70-1-PA.jpg        0.278836
# 136                         covid-19-pneumonia-42.jpeg        0.267903
# 117  covid-19-pneumonia-evolution-over-a-week-1-day...        0.263543
# 134                    covid-19-pneumonia-43-day2.jpeg        0.248272
# 125                         covid-19-caso-70-2-APS.jpg        0.237861
# 118  covid-19-pneumonia-evolution-over-a-week-1-day...        0.236816
# 102              pneumocystis-jiroveci-pneumonia-2.png        0.217411

# %% [markdown]
# ## Medium

# %%
ep.pl.umap(adata[adata.obs.severity == "Moderate"], color="dpt_pseudotime")

# %%
normal_only = adata.obs[adata.obs.severity == "Moderate"].sort_values(
    by="dpt_pseudotime", ascending=False
)
normal_only
# Out:
#     geographic_mean  severity  \
# 47             Mild  Moderate
# 20         Moderate  Moderate
# 57             Mild  Moderate
# 56         Moderate  Moderate
# 21         Moderate  Moderate
# 44         Moderate  Moderate
# 62         Moderate  Moderate
# 70         Moderate  Moderate
# 40         Moderate  Moderate
# 55         Moderate  Moderate
# 75             Mild  Moderate
# 53         Moderate  Moderate
# 41         Moderate  Moderate
# 52         Moderate  Moderate
# 60         Moderate  Moderate
# 83             Mild  Moderate
# 71         Moderate  Moderate
# 88         Moderate  Moderate
# 65         Moderate  Moderate
# 68         Moderate  Moderate
# 72         Moderate  Moderate
# 66         Moderate  Moderate
# 73         Moderate  Moderate
# 74         Moderate  Moderate
# 69         Moderate  Moderate
# 97         Moderate  Moderate
# 109        Moderate  Moderate
# 67         Moderate  Moderate
# 80         Moderate  Moderate
# 127            Mild  Moderate
# 126            Mild  Moderate
# 99             Mild  Moderate
# 95         Moderate  Moderate
# 108        Moderate  Moderate
# 103            Mild  Moderate
# 98         Moderate  Moderate
# 91             Mild  Moderate
# 122        Moderate  Moderate
# 87         Moderate  Moderate
# 121        Moderate  Moderate
# 130            Mild  Moderate
# 94         Moderate  Moderate
# 92         Moderate  Moderate
# 129            Mild  Moderate
# 112            Mild  Moderate
# 114          Normal  Moderate
# 131            Mild  Moderate
# 111        Moderate  Moderate
# 104            Mild  Moderate
# 105            Mild  Moderate
# 135          Normal  Moderate
# 106          Normal  Moderate
# 132            Mild  Moderate
#
#                                             image_name  dpt_pseudotime
# 47           2C26F453-AF3B-4517-BB9E-802CF2179543.jpeg        0.946343
# 20              1-s2.0-S0929664620300449-gr2_lrg-d.jpg        0.927422
# 57                             kjr-21-e24-g002-l-a.jpg        0.831903
# 56                             kjr-21-e24-g001-l-a.jpg        0.789722
# 21                        covid-19-pneumonia-15-PA.jpg        0.781163
# 44           6CB4EFC6-68FA-4CD5-940C-BEFA8DAFE9A7.jpeg        0.772996
# 62        1-s2.0-S1684118220300682-main.pdf-003-b2.png        0.737372
# 70                             kjr-21-e25-g001-l-a.jpg        0.737170
# 40           7AF6C1AF-D249-4BD2-8C26-449304105D03.jpeg        0.715906
# 55                               ciaa199.pdf-001-b.png        0.710202
# 75           2B8649B2-00C4-4233-85D5-1CE240CF233B.jpeg        0.660074
# 53           80446565-E090-4187-A031-9D3CEAA586C8.jpeg        0.613183
# 41           1B734A89-A1BF-49A8-A1D3-66FAFA4FAC5D.jpeg        0.612481
# 52           446B2CB6-B572-40AB-B01F-1910CA07086A.jpeg        0.587624
# 60        1-s2.0-S1684118220300682-main.pdf-002-a2.png        0.585553
# 83                  cavitating-pneumonia-4-day0-PA.jpg        0.580489
# 71           03BF7561-A9BA-4C3C-B8A0-D3E585F73F3C.jpeg        0.578941
# 88   covid-19-pneumonia-rapidly-progressive-admissi...        0.578916
# 65           5931B64A-7B97-485D-BE60-3F1EA76BC4F0.jpeg        0.555442
# 68                       5e6dd879fde9502400e58b2f.jpeg        0.553001
# 72      figure1-5e75d0940b71e1b702629659-98-right.jpeg        0.549487
# 66           C6EA0BE5-B01E-4113-B194-18D956675E25.jpeg        0.539130
# 73           1F6343EE-AFEC-4B7D-97F5-62797EE18767.jpeg        0.518102
# 74           5A78BCA9-5B7A-440D-8A4E-AE7710EA6EAD.jpeg        0.516906
# 69                           covid-19-pneumonia-19.jpg        0.508978
# 97            pneumocystis-jirovecii-pneumonia-3-1.jpg        0.498322
# 109  1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf...        0.485910
# 67            7EF28E12-F628-4BEC-A8C5-E6277C2E4F60.png        0.462786
# 80                     parapneumonic-effusion-1-PA.png        0.453715
# 127                          covid-19-pneumonia-53.jpg        0.444058
# 126          4e43e48d52c9e2d4c6c1fb9bc1544f_jumbo.jpeg        0.423588
# 99                        pneumocystis-pneumonia-1.jpg        0.422316
# 95                           covid-19-pneumonia-28.png        0.420404
# 108  1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf...        0.414036
# 103             pneumocystis-jirovecii-pneumonia-2.jpg        0.397871
# 98            pneumocystis-jirovecii-pneumonia-3-2.jpg        0.388751
# 91   covid-19-rapidly-progressive-acute-respiratory...        0.388032
# 122          A7E260CE-8A00-4C5F-A7F5-27336527A981.jpeg        0.377780
# 87           9fdd3c3032296fd04d2cad5d9070d4_jumbo.jpeg        0.362436
# 121                     covid-19-pneumonia-23-day9.jpg        0.348667
# 130  post-intubuation-pneumomediastium-and-pneumoth...        0.333575
# 94   covid-19-infection-exclusive-gastrointestinal-...        0.327886
# 92   covid-19-rapidly-progressive-acute-respiratory...        0.324725
# 129  post-intubuation-pneumomediastium-and-pneumoth...        0.317705
# 112                     covid-19-pneumonia-24-day6.jpg        0.313335
# 114                    covid-19-pneumonia-24-day12.jpg        0.307264
# 131                     covid-19-pneumonia-49-day4.jpg        0.303179
# 111  1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf...        0.266500
# 104           pneumocystis-jiroveci-pneumonia-4-PA.png        0.265627
# 105                         legionella-pneumonia-1.png        0.245360
# 135                          covid-19-pneumonia-40.jpg        0.234752
# 106                         legionella-pneumonia-2.jpg        0.217048
# 132                     covid-19-pneumonia-49-day8.jpg        0.047803

# %% [markdown]
# ## Severe

# %%
ep.pl.umap(adata[adata.obs.severity == "Severe"], color="dpt_pseudotime")

# %%
adata[adata.obs.severity == "Severe"].obs.sort_values(
    by="dpt_pseudotime", ascending=False
)
# Out:
#     geographic_mean severity  \
# 46         Moderate   Severe
# 54         Moderate   Severe
# 35         Moderate   Severe
# 28           Severe   Severe
# 13         Moderate   Severe
# 14           Severe   Severe
# 39         Moderate   Severe
# 48         Moderate   Severe
# 38         Moderate   Severe
# 51         Moderate   Severe
# 36         Moderate   Severe
# 16           Severe   Severe
# 64         Moderate   Severe
# 63         Moderate   Severe
# 50         Moderate   Severe
# 61         Moderate   Severe
# 93         Moderate   Severe
# 77         Moderate   Severe
# 96         Moderate   Severe
# 78         Moderate   Severe
# 81         Moderate   Severe
# 79         Moderate   Severe
# 120        Moderate   Severe
# 110        Moderate   Severe
# 86         Moderate   Severe
# 89         Moderate   Severe
#
#                                             image_name  dpt_pseudotime
# 46           F63AB6CE-1968-4154-A70F-913AF154F53D.jpeg        1.000000
# 54           7E335538-2F86-424E-A0AB-6397783A38D0.jpeg        0.981315
# 35           F2DE909F-E19C-4900-92F5-8F435B031AC6.jpeg        0.961324
# 28                                     pneumonia-7.jpg        0.920858
# 13                          ryct.2020200028.fig1a.jpeg        0.887931
# 14                            jkms-35-e79-g001-l-a.jpg        0.845008
# 39            23E99E2E-447C-46E5-8EB2-D35D12473C39.png        0.839051
# 48           93FE0BB1-022D-4F24-9727-987A07975FFB.jpeg        0.825884
# 38           1312A392-67A3-4EBF-9319-810CF6DA5EF6.jpeg        0.790421
# 51           5CBC2E94-D358-401E-8928-965CCD965C5C.jpeg        0.779597
# 36           31BA3780-2323-493F-8AED-62081B9C383B.jpeg        0.703272
# 16                         radiol.2020200490.fig3.jpeg        0.685570
# 64           171CB377-62FF-4B76-906C-F3787A01CB2E.jpeg        0.683498
# 63           FE9F9A5D-2830-46F9-851B-1FF4534959BE.jpeg        0.614034
# 50           E63574A7-4188-4C8D-8D17-9D67A18A1AFA.jpeg        0.607793
# 61        1-s2.0-S1684118220300682-main.pdf-003-b1.png        0.584947
# 93   covid-19-rapidly-progressive-acute-respiratory...        0.532040
# 77                     pneumococcal-pneumonia-day0.jpg        0.518328
# 96                          klebsiella-pneumonia-1.jpg        0.496739
# 78                     pneumococcal-pneumonia-day7.jpg        0.478110
# 81                 right-upper-lobe-pneumonia-9-PA.jpg        0.469380
# 79                    pneumococcal-pneumonia-day35.jpg        0.429469
# 120                     covid-19-pneumonia-23-day3.jpg        0.402064
# 110  1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf...        0.321869
# 86           58cb9263f16e94305c730685358e4e_jumbo.jpeg        0.311217
# 89   covid-19-pneumonia-rapidly-progressive-12-hour...        0.263231

# %% [markdown]
# ## Critical

# %%
ep.pl.umap(adata[adata.obs.severity == "Critical"], color="dpt_pseudotime")

# %%
adata[adata.obs.geographic_mean == "Severe"].obs.sort_values(
    by="dpt_pseudotime", ascending=False
)
# Out:
#    geographic_mean  severity  \
# 32          Severe  Critical
# 29          Severe  Critical
# 9           Severe  Critical
# 5           Severe  Critical
# 8           Severe  Critical
# 12          Severe  Critical
# 4           Severe  Critical
# 7           Severe  Critical
# 28          Severe    Severe
# 6           Severe  Critical
# 10          Severe  Critical
# 11          Severe  Critical
# 3           Severe  Critical
# 15          Severe  Critical
# 33          Severe  Critical
# 0           Severe  Critical
# 1           Severe  Critical
# 23          Severe  Critical
# 14          Severe    Severe
# 17          Severe  Critical
# 26          Severe  Critical
# 22          Severe  Critical
# 2           Severe  Critical
# 18          Severe  Critical
# 30          Severe  Critical
# 25          Severe  Critical
# 24          Severe  Critical
# 43          Severe  Critical
# 16          Severe    Severe
# 27          Severe  Critical
# 42          Severe  Critical
# 76          Severe  Critical
#
#                                            image_name  dpt_pseudotime
# 32          E1724330-1866-4581-8CD8-CEC9B8AFEDDE.jpeg        0.996933
# 29          39EE8E69-5801-48DE-B6E3-BE7D1BCF3092.jpeg        0.993020
# 9                            nejmoa2001191_f3-PA.jpeg        0.960734
# 5   SARS-10.1148rg.242035193-g04mr34g05x-Fig5-day9...        0.948331
# 8                            nejmoa2001191_f1-PA.jpeg        0.947326
# 12                          ryct.2020200034.fig2.jpeg        0.939197
# 4   SARS-10.1148rg.242035193-g04mr34g04b-Fig4b-day...        0.928153
# 7               nCoV-radiol.2020200269.fig1-day7.jpeg        0.923782
# 28                                    pneumonia-7.jpg        0.920858
# 6   SARS-10.1148rg.242035193-g04mr34g07b-Fig7b-day...        0.919188
# 10                              nejmoa2001191_f4.jpeg        0.908869
# 11                           nejmoa2001191_f5-PA.jpeg        0.905816
# 3   SARS-10.1148rg.242035193-g04mr34g04a-Fig4a-day...        0.901763
# 15                           jkms-35-e79-g001-l-b.jpg        0.892204
# 33          8FDE8DBA-CFBD-4B4C-B1A4-6F36A93B7E87.jpeg        0.874863
# 0                               nejmc2001573_f1a.jpeg        0.866439
# 1                                   lancet-case2a.jpg        0.859657
# 23                        covid-19-pneumonia-7-PA.jpg        0.849832
# 14                           jkms-35-e79-g001-l-a.jpg        0.845008
# 17             1-s2.0-S0929664620300449-gr2_lrg-a.jpg        0.840279
# 26     acute-respiratory-distress-syndrome-ards-1.jpg        0.819436
# 22                           covid-19-pneumonia-2.jpg        0.816911
# 2                                   lancet-case2b.jpg        0.816588
# 18             1-s2.0-S0929664620300449-gr2_lrg-b.jpg        0.798893
# 30          7C69C012-7479-493F-8722-ABC29C60A2DD.jpeg        0.796358
# 25                          covid-19-pneumonia-12.jpg        0.781699
# 24                       covid-19-pneumonia-14-PA.png        0.755739
# 43          85E52EB3-56E9-4D67-82DA-DEA247C82886.jpeg        0.699934
# 16                        radiol.2020200490.fig3.jpeg        0.685570
# 27                    pneumocystis-pneumonia-2-PA.png        0.657429
# 42          CD50BA96-6982-4C80-AE7B-5F67ACDBFA56.jpeg        0.633266
# 76          6C94A287-C059-46A0-8600-AFB95F4727B7.jpeg        0.570824
