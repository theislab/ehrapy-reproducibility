# %%
from torchinfo import summary
import torch
import torch.nn as nn
import torch.nn.functional as F
from diabetic_retinopathy.latent_extractors.predictors.opts import ModelOptions
from diabetic_retinopathy.latent_extractors.predictors.NNExtractor import NNExtractor
from diabetic_retinopathy.constants import (
    DATASPLIT_DIR,
    MODELS_DIR,
    PROCESSED_DIR,
    PhaseType,
    TRAIN_CONFIG,
)
import toml

# %%
from ehrapylat.latent_extractors.predictors.models.LatentExtractor import Models

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
models = [el for el in list(Models.__members__.keys()) if "FC" in el and "18" in el]
models
# Out:
# ['resnet18ImgNetFC', 'resnet18RawFC', 'resnet18ActBasedFC']

# %%
for ind_config, model in enumerate(models):

    config_path = TRAIN_CONFIG / "standart_configs" / "config-FC_cl.toml"
    config_dict = toml.load(config_path)

    config_dict["model"] = model
    # print(config_dict)
    with open(TRAIN_CONFIG / "running_configs" / f"config-{ind_config}.toml", "w") as f:
        toml.dump(config_dict, f)

    config_dict = toml.load(
        TRAIN_CONFIG / "running_configs" / f"config-{ind_config}.toml"
    )
    print(config_dict)
# Out:
# {'model_type': 'resnet18ActBasedFC', 'nn_loss': 'CrossEntropyLoss', 'find_lr': False, 'lr': 0.0001, 'overwrite': False, 'num_workers': 2, 'batch_size': 64, 'lr_policy': 'constant', 'num_epochs': 2000, 'augmentations': True, 'model': 'resnet18ImgNetFC'}
# {'model_type': 'resnet18ActBasedFC', 'nn_loss': 'CrossEntropyLoss', 'find_lr': False, 'lr': 0.0001, 'overwrite': False, 'num_workers': 2, 'batch_size': 64, 'lr_policy': 'constant', 'num_epochs': 2000, 'augmentations': True, 'model': 'resnet18RawFC'}
# {'model_type': 'resnet18ActBasedFC', 'nn_loss': 'CrossEntropyLoss', 'find_lr': False, 'lr': 0.0001, 'overwrite': False, 'num_workers': 2, 'batch_size': 64, 'lr_policy': 'constant', 'num_epochs': 2000, 'augmentations': True, 'model': 'resnet18ActBasedFC'}

# %%
OPTIONS = "--config_path running_configs/config-0.toml --batch_size 64 --profiler simple --limit_train_batches 1 --limit_val_batches 1 --nn_model_id test"

# %%
# !python -u /dss/dsshome1/02/di93zov/Projects/ehrapy_DR_latents/ehrapy_latents/ehrapylat/cli/cmdline.py train $OPTIONS
# Out:
# Readng config files from running_configs/config-0.toml
# Loading inference configurations from /dss/dsshome1/02/di93zov/Projects/ehrapy_DR_latents/ehrapy_latents/project_folder/configs/train_configs/running_configs/config-0.toml:
# Conf file was sucessfully loaded
# /dss/dsshome1/02/di93zov/Projects/ehrapy_DR_latents/ehrapy_latents/project_folder/experiments/resnet18ImgNetFC-test-version0
# /dss/dsshome1/02/di93zov/Projects/ehrapy_DR_latents/ehrapy_latents/project_folder/experiments/resnet18ImgNetFC-test-version0 resnet18ImgNetFC-test-version0
# /dss/dsshome1/02/di93zov/anaconda3/envs/ehrapy/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /dss/dsshome1/02/di93zov/anaconda3/envs/ehrapy/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /dss/dsshome1/02/di93zov/anaconda3/envs/ehrapy/lib/python3.9/site-packages/pytorch_lightning/utilities/parsing.py:197: UserWarning: Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.
#   rank_zero_warn(
# Compose(
#     Resize(size=(256, 256), interpolation=bilinear, max_size=None, antialias=None)
#     CenterCrop(size=(224, 224))
#     RandomHorizontalFlip(p=0.5)
#     ToPILImage()
#     RandAugment(n=2, ops=
# 	AugmentOp(name=AutoContrast, p=0.5, m=9, mstd=0.5)
# 	AugmentOp(name=Equalize, p=0.5, m=9, mstd=0.5)
# 	AugmentOp(name=Invert, p=0.5, m=9, mstd=0.5)
# 	AugmentOp(name=Rotate, p=0.5, m=9, mstd=0.5)
# 	AugmentOp(name=Posterize, p=0.5, m=9, mstd=0.5)
# 	AugmentOp(name=Solarize, p=0.5, m=9, mstd=0.5)
# 	AugmentOp(name=SolarizeAdd, p=0.5, m=9, mstd=0.5)
# 	AugmentOp(name=Color, p=0.5, m=9, mstd=0.5)
# 	AugmentOp(name=Contrast, p=0.5, m=9, mstd=0.5)
# 	AugmentOp(name=Brightness, p=0.5, m=9, mstd=0.5)
# 	AugmentOp(name=Sharpness, p=0.5, m=9, mstd=0.5)
# 	AugmentOp(name=ShearX, p=0.5, m=9, mstd=0.5)
# 	AugmentOp(name=ShearY, p=0.5, m=9, mstd=0.5)
# 	AugmentOp(name=TranslateXRel, p=0.5, m=9, mstd=0.5)
# 	AugmentOp(name=TranslateYRel, p=0.5, m=9, mstd=0.5))
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ) Compose(
#     Resize(size=(256, 256), interpolation=bilinear, max_size=None, antialias=None)
#     CenterCrop(size=(224, 224))
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ) False
# loaded labels from /dss/dsshome1/02/di93zov/Projects/ehrapy_DR_latents/ehrapy_latents/project_folder/data/data_split/train_df.csv, shape: (18386, 6)
# loaded labels from /dss/dsshome1/02/di93zov/Projects/ehrapy_DR_latents/ehrapy_latents/project_folder/data/data_split/val_df.csv, shape: (3066, 6)
# [rank: 0] Global seed set to 5
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_train_batches=1)` was configured so 1 batch per epoch will be used.
# `Trainer(limit_val_batches=1)` was configured so 1 batch will be used.
# loaded labels from /dss/dsshome1/02/di93zov/Projects/ehrapy_DR_latents/ehrapy_latents/project_folder/data/data_split/train_df.csv, shape: (18386, 6)
# loaded labels from /dss/dsshome1/02/di93zov/Projects/ehrapy_DR_latents/ehrapy_latents/project_folder/data/data_split/val_df.csv, shape: (3066, 6)
#
#   | Name      | Type             | Params
# -----------------------------------------------
# 0 | model     | ResNetAdapted    | 11.3 M
# 1 | criterion | CrossEntropyLoss | 0
# -----------------------------------------------
# 11.3 M    Trainable params
# 0         Non-trainable params
# 11.3 M    Total params
# 45.397    Total estimated model params size (MB)
# SLURM auto-requeueing enabled. Setting signal handlers.
# Sanity Checking: 0it [00:00, ?it/s]/dss/dsshome1/02/di93zov/anaconda3/envs/ehrapy/lib/python3.9/site-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 2 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /dss/dsshome1/02/di93zov/anaconda3/envs/ehrapy/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 56 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Sanity Checking DataLoader 0:   0%|                       | 0/1 [00:00<?, ?it/s]/dss/dsshome1/02/di93zov/anaconda3/envs/ehrapy/lib/python3.9/site-packages/pytorch_lightning/utilities/data.py:76: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 64. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /dss/dsshome1/02/di93zov/anaconda3/envs/ehrapy/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:430: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 56 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Epoch 0: 100%|█| 1/1 [01:38<00:00, 98.73s/it, v_num=sion, train_loss=1.640, trai
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|█| 1/1 [02:35<00:00, 155.92s/it, v_num=sion, train_loss=1.640, tra
# Epoch 1: 100%|█| 1/1 [01:40<00:00, 100.88s/it, v_num=sion, train_loss=1.510, tra
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 1: 100%|█| 1/1 [02:37<00:00, 157.46s/it, v_num=sion, train_loss=1.510, tra
# Epoch 2: 100%|█| 1/1 [01:40<00:00, 100.87s/it, v_num=sion, train_loss=1.340, tra
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 2: 100%|█| 1/1 [02:37<00:00, 157.44s/it, v_num=sion, train_loss=1.340, tra
# Epoch 3: 100%|█| 1/1 [01:40<00:00, 100.83s/it, v_num=sion, train_loss=1.110, tra
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 3: 100%|█| 1/1 [02:37<00:00, 157.38s/it, v_num=sion, train_loss=1.110, tra
# Epoch 4: 100%|█| 1/1 [01:40<00:00, 100.99s/it, v_num=sion, train_loss=0.818, tra
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 4: 100%|█| 1/1 [02:37<00:00, 157.60s/it, v_num=sion, train_loss=0.818, tra
# Epoch 5: 100%|█| 1/1 [01:41<00:00, 101.40s/it, v_num=sion, train_loss=0.631, tra
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 5: 100%|█| 1/1 [02:38<00:00, 158.00s/it, v_num=sion, train_loss=0.631, tra
# Epoch 6: 100%|█| 1/1 [01:41<00:00, 101.45s/it, v_num=sion, train_loss=0.516, tra
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 6: 100%|█| 1/1 [02:38<00:00, 158.01s/it, v_num=sion, train_loss=0.516, tra
# Epoch 7: 100%|█| 1/1 [01:47<00:00, 107.61s/it, v_num=sion, train_loss=0.599, tra
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 7: 100%|█| 1/1 [02:44<00:00, 164.20s/it, v_num=sion, train_loss=0.599, tra
# Epoch 8: 100%|█| 1/1 [01:41<00:00, 101.41s/it, v_num=sion, train_loss=0.536, tra
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 8: 100%|█| 1/1 [02:38<00:00, 158.02s/it, v_num=sion, train_loss=0.536, tra
# Epoch 9: 100%|█| 1/1 [01:41<00:00, 101.39s/it, v_num=sion, train_loss=0.347, tra
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 9: 100%|█| 1/1 [02:37<00:00, 157.91s/it, v_num=sion, train_loss=0.347, tra
# Epoch 10: 100%|█| 1/1 [01:41<00:00, 101.30s/it, v_num=sion, train_loss=0.356, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 10: 100%|█| 1/1 [02:37<00:00, 157.93s/it, v_num=sion, train_loss=0.356, tr
# Epoch 11: 100%|█| 1/1 [01:41<00:00, 101.30s/it, v_num=sion, train_loss=0.385, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 11: 100%|█| 1/1 [02:37<00:00, 157.85s/it, v_num=sion, train_loss=0.385, tr
# Epoch 12: 100%|█| 1/1 [01:41<00:00, 101.36s/it, v_num=sion, train_loss=0.415, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 12: 100%|█| 1/1 [02:37<00:00, 157.91s/it, v_num=sion, train_loss=0.415, tr
# Epoch 13: 100%|█| 1/1 [01:41<00:00, 101.31s/it, v_num=sion, train_loss=0.362, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 13: 100%|█| 1/1 [02:37<00:00, 157.84s/it, v_num=sion, train_loss=0.362, tr
# Epoch 14: 100%|█| 1/1 [01:41<00:00, 101.29s/it, v_num=sion, train_loss=0.384, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 14: 100%|█| 1/1 [02:37<00:00, 157.90s/it, v_num=sion, train_loss=0.384, tr
# Epoch 15: 100%|█| 1/1 [01:41<00:00, 101.32s/it, v_num=sion, train_loss=0.367, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 15: 100%|█| 1/1 [02:37<00:00, 157.89s/it, v_num=sion, train_loss=0.367, tr
# Epoch 16: 100%|█| 1/1 [01:41<00:00, 101.34s/it, v_num=sion, train_loss=0.424, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 16: 100%|█| 1/1 [02:37<00:00, 157.95s/it, v_num=sion, train_loss=0.424, tr
# Epoch 17: 100%|█| 1/1 [01:41<00:00, 101.41s/it, v_num=sion, train_loss=0.320, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 17: 100%|█| 1/1 [02:37<00:00, 157.98s/it, v_num=sion, train_loss=0.320, tr
# Epoch 18: 100%|█| 1/1 [01:41<00:00, 101.28s/it, v_num=sion, train_loss=0.319, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 18: 100%|█| 1/1 [02:37<00:00, 157.82s/it, v_num=sion, train_loss=0.319, tr
# Epoch 19: 100%|█| 1/1 [01:41<00:00, 101.35s/it, v_num=sion, train_loss=0.319, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 19: 100%|█| 1/1 [02:37<00:00, 157.96s/it, v_num=sion, train_loss=0.319, tr
# Epoch 20: 100%|█| 1/1 [01:41<00:00, 101.48s/it, v_num=sion, train_loss=0.307, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 20: 100%|█| 1/1 [02:38<00:00, 158.08s/it, v_num=sion, train_loss=0.307, tr
# Epoch 21: 100%|█| 1/1 [01:41<00:00, 101.39s/it, v_num=sion, train_loss=0.299, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 21: 100%|█| 1/1 [02:37<00:00, 157.97s/it, v_num=sion, train_loss=0.299, tr
# Epoch 22: 100%|█| 1/1 [01:41<00:00, 101.35s/it, v_num=sion, train_loss=0.275, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 22: 100%|█| 1/1 [02:37<00:00, 157.97s/it, v_num=sion, train_loss=0.275, tr
# Epoch 23: 100%|█| 1/1 [01:44<00:00, 104.94s/it, v_num=sion, train_loss=0.269, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 23: 100%|█| 1/1 [02:41<00:00, 161.73s/it, v_num=sion, train_loss=0.269, tr
# Epoch 24: 100%|█| 1/1 [01:46<00:00, 106.20s/it, v_num=sion, train_loss=0.169, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 24: 100%|█| 1/1 [02:42<00:00, 162.74s/it, v_num=sion, train_loss=0.169, tr
# Epoch 25: 100%|█| 1/1 [01:41<00:00, 101.41s/it, v_num=sion, train_loss=0.186, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 25: 100%|█| 1/1 [02:38<00:00, 158.12s/it, v_num=sion, train_loss=0.186, tr
# Epoch 26: 100%|█| 1/1 [01:44<00:00, 104.43s/it, v_num=sion, train_loss=0.321, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 26: 100%|█| 1/1 [02:41<00:00, 161.06s/it, v_num=sion, train_loss=0.321, tr
# Epoch 27: 100%|█| 1/1 [01:42<00:00, 102.96s/it, v_num=sion, train_loss=0.378, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 27: 100%|█| 1/1 [02:39<00:00, 159.54s/it, v_num=sion, train_loss=0.378, tr
# Epoch 28: 100%|█| 1/1 [01:41<00:00, 101.48s/it, v_num=sion, train_loss=0.266, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 28: 100%|█| 1/1 [02:38<00:00, 158.09s/it, v_num=sion, train_loss=0.266, tr
# Epoch 29: 100%|█| 1/1 [01:41<00:00, 101.34s/it, v_num=sion, train_loss=0.225, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 29: 100%|█| 1/1 [02:37<00:00, 157.93s/it, v_num=sion, train_loss=0.225, tr
# Epoch 30: 100%|█| 1/1 [01:41<00:00, 101.45s/it, v_num=sion, train_loss=0.244, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 30: 100%|█| 1/1 [02:38<00:00, 158.05s/it, v_num=sion, train_loss=0.244, tr
# Epoch 31: 100%|█| 1/1 [01:41<00:00, 101.34s/it, v_num=sion, train_loss=0.176, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 31: 100%|█| 1/1 [02:37<00:00, 157.91s/it, v_num=sion, train_loss=0.176, tr
# Epoch 32: 100%|█| 1/1 [02:13<00:00, 133.77s/it, v_num=sion, train_loss=0.124, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 32: 100%|█| 1/1 [03:59<00:00, 239.54s/it, v_num=sion, train_loss=0.124, tr
# Epoch 33: 100%|█| 1/1 [02:20<00:00, 140.16s/it, v_num=sion, train_loss=0.123, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 33: 100%|█| 1/1 [03:43<00:00, 223.66s/it, v_num=sion, train_loss=0.123, tr
# Epoch 34: 100%|█| 1/1 [02:16<00:00, 136.64s/it, v_num=sion, train_loss=0.134, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 34: 100%|█| 1/1 [03:32<00:00, 212.39s/it, v_num=sion, train_loss=0.134, tr
# Epoch 35: 100%|█| 1/1 [02:51<00:00, 171.48s/it, v_num=sion, train_loss=0.329, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 35: 100%|█| 1/1 [04:09<00:00, 249.97s/it, v_num=sion, train_loss=0.329, tr
# Epoch 36: 100%|█| 1/1 [01:41<00:00, 101.28s/it, v_num=sion, train_loss=0.192, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 36: 100%|█| 1/1 [02:37<00:00, 157.87s/it, v_num=sion, train_loss=0.192, tr
# Epoch 37: 100%|█| 1/1 [01:41<00:00, 101.47s/it, v_num=sion, train_loss=0.242, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 37: 100%|█| 1/1 [02:38<00:00, 158.02s/it, v_num=sion, train_loss=0.242, tr
# Epoch 38: 100%|█| 1/1 [01:41<00:00, 101.32s/it, v_num=sion, train_loss=0.498, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 38: 100%|█| 1/1 [02:37<00:00, 157.96s/it, v_num=sion, train_loss=0.498, tr
# Epoch 39: 100%|█| 1/1 [01:41<00:00, 101.33s/it, v_num=sion, train_loss=0.580, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 39: 100%|█| 1/1 [02:37<00:00, 157.92s/it, v_num=sion, train_loss=0.580, tr
# Epoch 40: 100%|█| 1/1 [01:41<00:00, 101.31s/it, v_num=sion, train_loss=0.196, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 40: 100%|█| 1/1 [02:37<00:00, 157.86s/it, v_num=sion, train_loss=0.196, tr
# Epoch 41: 100%|█| 1/1 [01:41<00:00, 101.43s/it, v_num=sion, train_loss=0.358, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 41: 100%|█| 1/1 [02:38<00:00, 158.02s/it, v_num=sion, train_loss=0.358, tr
# Epoch 42: 100%|█| 1/1 [01:41<00:00, 101.39s/it, v_num=sion, train_loss=0.176, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 42: 100%|█| 1/1 [02:37<00:00, 157.92s/it, v_num=sion, train_loss=0.176, tr
# Epoch 43: 100%|█| 1/1 [01:41<00:00, 101.38s/it, v_num=sion, train_loss=0.356, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 43: 100%|█| 1/1 [02:42<00:00, 162.18s/it, v_num=sion, train_loss=0.356, tr
# Epoch 44: 100%|█| 1/1 [01:41<00:00, 101.24s/it, v_num=sion, train_loss=0.156, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 44: 100%|█| 1/1 [02:41<00:00, 161.93s/it, v_num=sion, train_loss=0.156, tr
# Epoch 45: 100%|█| 1/1 [01:46<00:00, 106.01s/it, v_num=sion, train_loss=0.184, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 45: 100%|█| 1/1 [02:42<00:00, 162.57s/it, v_num=sion, train_loss=0.184, tr
# Epoch 46: 100%|█| 1/1 [01:48<00:00, 108.99s/it, v_num=sion, train_loss=0.234, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 46: 100%|█| 1/1 [03:04<00:00, 184.59s/it, v_num=sion, train_loss=0.234, tr
# Epoch 47: 100%|█| 1/1 [02:10<00:00, 130.77s/it, v_num=sion, train_loss=0.228, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 47: 100%|█| 1/1 [03:26<00:00, 206.34s/it, v_num=sion, train_loss=0.228, tr
# Epoch 48: 100%|█| 1/1 [02:10<00:00, 130.28s/it, v_num=sion, train_loss=0.176, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 48: 100%|█| 1/1 [03:25<00:00, 205.91s/it, v_num=sion, train_loss=0.176, tr
# Epoch 49: 100%|█| 1/1 [02:40<00:00, 160.61s/it, v_num=sion, train_loss=0.102, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 49: 100%|█| 1/1 [04:24<00:00, 264.97s/it, v_num=sion, train_loss=0.102, tr
# Epoch 50: 100%|█| 1/1 [02:18<00:00, 138.04s/it, v_num=sion, train_loss=0.0949, t
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 50: 100%|█| 1/1 [03:44<00:00, 224.39s/it, v_num=sion, train_loss=0.0949, t
# Epoch 51: 100%|█| 1/1 [02:10<00:00, 130.64s/it, v_num=sion, train_loss=0.416, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 51: 100%|█| 1/1 [03:08<00:00, 188.89s/it, v_num=sion, train_loss=0.416, tr
# Epoch 52: 100%|█| 1/1 [01:41<00:00, 101.32s/it, v_num=sion, train_loss=0.178, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 52: 100%|█| 1/1 [02:37<00:00, 157.90s/it, v_num=sion, train_loss=0.178, tr
# Epoch 53: 100%|█| 1/1 [02:39<00:00, 159.04s/it, v_num=sion, train_loss=0.237, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 53: 100%|█| 1/1 [04:03<00:00, 243.33s/it, v_num=sion, train_loss=0.237, tr
# Epoch 54: 100%|█| 1/1 [01:41<00:00, 101.27s/it, v_num=sion, train_loss=0.120, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 54: 100%|█| 1/1 [02:37<00:00, 157.88s/it, v_num=sion, train_loss=0.120, tr
# Epoch 55: 100%|█| 1/1 [01:41<00:00, 101.26s/it, v_num=sion, train_loss=0.221, tr
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/1 [00:00<?, ?it/s]
# Epoch 55: 100%|█| 1/1 [02:37<00:00, 157.76s/it, v_num=sion, train_loss=0.221, tr
# Epoch 56:   0%| | 0/1 [00:00<?, ?it/s, v_num=sion, train_loss=0.221, train_f1=0.^C
# /dss/dsshome1/02/di93zov/anaconda3/envs/ehrapy/lib/python3.9/site-packages/pytorch_lightning/trainer/call.py:54: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")
# CPU usage: 2.0%
# Epoch 56:   0%| | 0/1 [00:49<?, ?it/s, v_num=sion, train_loss=0.221, train_f1=0.

# %%
ckpt_path = "/dss/dsshome1/02/di93zov/Projects/ehrapy_DR_latents/ehrapy_latents/project_folder/experiments/resnet18RawFC-test_version2/last/checkpoint-epoch=80-step=23328.ckpt"

# %%
import torch

state_dict = torch.load(ckpt_path, map_location=torch.device("cpu"))

# %%
state_dict["hyper_parameters"]["lr"]
# Out:
# 0.0001

# %%
state_dict["hyper_parameters"]
# Out:
# {'model_name': 'resnet18RawFC-version1',
#  'model': 'resnet18RawFC',
#  'module': 'ResNetFC',
#  'model_id': 'resnet18RawFC',
#  'opts': <ehrapylat.latent_extractors.predictors.opts.ModelOptions at 0x2ac0cf401f10>,
#  'initialization': <ResNetInit.Raw: 'Raw'>,
#  'num_classes': 5,
#  'config_path': 'running_configs/config-1.toml',
#  'batch_size': 64,
#  'profiler': 'simple',
#  'overwrite': False,
#  'num_workers': 2,
#  'lr_policy': 'constant',
#  'lr': 0.0001,
#  'find_lr': False,
#  'num_epochs': 2000,
#  'n_ep_decay': 600,
#  'gpu': False,
#  'limit_train_batches': None,
#  'limit_val_batches': None,
#  'resume': False,
#  'nn_model_id': None,
#  'nn_loss': 'CrossEntropyLoss',
#  'weighted_sampler': False,
#  'seed': 5,
#  'deterministic': True,
#  'compensation': 'memory',
#  'gradient_clip_val': None,
#  'model_type': 'resnet18ActBasedFC',
#  'augmentations': True,
#  'train': True,
#  'model_path': '/dss/dsshome1/02/di93zov/Projects/ehrapy_DR_latents/ehrapy_latents/project_folder/experiments/resnet18RawFC-version1'}
